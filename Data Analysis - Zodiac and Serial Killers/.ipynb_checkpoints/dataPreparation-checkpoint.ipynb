# %%
#https://github.com/lhehnke/serial-killers/

import pandas as pd
import pyreadr

result = pyreadr.read_r('serial_killers_data.rds')

df = result[None]
df.to_csv('serial_killers.csv', index=False)

# %%
listOfKillers = df['name'].to_list()
listOfKillers
# Out:
# ['Abdallah al-Hubal',
#  'Abdelali Amer',
#  'Abraão José Bueno',
#  'Abul Djabar',
#  'Adnan Çolak',
#  'Adolf Seefeldt',
#  'Adolfo de Jesús Constanzo',
#  'Ahmad Suradji',
#  'Aileen Carol Wuornos',
#  'Aino Nykopp-Koski',
#  'Albert Edwards Burrows',
#  'Albert Fish',
#  'Albert Henry DeSalvo',
#  'Alexander Jurjewitsch Pitschuschkin',
#  'Alexander Nikolajewitsch Spessiwzew',
#  'Alexander Pearce',
#  'Alfred Engleder',
#  'Allan Legere',
#  'Allen Leroy Anderson',
#  'Altemio Sanchez',
#  'Alton Coleman',
#  'Amelia Elizabeth Dyer',
#  'Amy Archer-Gilligan',
#  'Anatoli Jemeljanowitsch Sliwko',
#  'Anatolij Onoprijenko',
#  'András Pándy',
#  'Andre Alexander',
#  'André Luiz Cassimiro',
#  'Andreas Bichel',
#  'Andrei Romanowitsch Tschikatilo',
#  'Andrew Phillip Cunanan',
#  'Andrew Urdiales',
#  'Angel Maturino Resendez',
#  'Angela Jane Johnson',
#  'Angelo Colalillo',
#  'Anjette Donovan Lyles',
#  'Anna Cunningham',
#  'Anna Margaretha Zwanziger',
#  'Anna Marie Hahn',
# ...
